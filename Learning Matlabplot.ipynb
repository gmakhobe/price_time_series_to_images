# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# Sigure containing single axis
fig, ax = plt.subplots()
# Plotting data on the figure
ax.plot([1, 2, 3, 4], [5, 2, 3, 1])
